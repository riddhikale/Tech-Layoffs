# %%
import numpy as np
import pandas as pd

import warnings

# %%
df= pd.read_csv('../data/layoffs.csv')
df.head()
# Out:
#        Company    Location_HQ   Industry  Laid_Off_Count        Date  \
# 0          Oda           Oslo       Food           150.0  2024-06-05
# 1       Pagaya       Tel Aviv    Finance           100.0  2024-06-05
# 2  Aleph Farms       Tel Aviv       Food            30.0  2024-06-05
# 3      MoonPay          Dover     Crypto            30.0  2024-06-05
# 4         Yext  New York City  Marketing             NaN  2024-06-05
#
#                                               Source  Funds_Raised     Stage  \
# 0  https://techcrunch.com/2024/06/05/softbank-bac...         691.0   Unknown
# 1  https://www.calcalistech.com/ctechnews/article...        2000.0  Post-IPO
# 2  https://www.calcalistech.com/ctechnews/article...         119.0   Unknown
# 3  https://www.theblock.co/post/298638/moonpay-la...         651.0   Unknown
# 4  https://www.investing.com/news/economy-news/ye...         117.0  Post-IPO
#
#             Date_Added        Country  Percentage List_of_Employees_Laid_Off
# ...

# %%
df['large_layoff'] = (df['Laid_Off_Count'] > 500).astype(int)
df['large_layoff'].value_counts()
# Out:
# large_layoff
# 0    3445
# 1     197
# Name: count, dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month

monthly_total = df.groupby(['year','month'])['Laid_Off_Count'].transform('sum')
df['wave_month'] = (monthly_total > 50000).astype(int)

# %%
df['Percentage'] = df['Percentage'].fillna(0)

# %%
monthly_total = df.groupby(['year','month'])['Laid_Off_Count'].transform('sum')
df['wave_month'] = (monthly_total > 50000).astype(int)

# %%
features = df[[
    'Funds_Raised',
    'year',
    'month',
    'Percentage',
    'wave_month'
]]

target = df['large_layoff']

# %%
features['Percentage'] = features['Percentage'].fillna(0)
features['Funds_Raised'] = features['Funds_Raised'].fillna(0)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features,
    target,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       682
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.94       729
#    macro avg       0.47      0.50      0.48       729
# weighted avg       0.88      0.94      0.90       729
#
# ROC-AUC: 0.5653740562800275
# [[682   0]
#  [ 47   0]]
# C:\Users\Riddhi Kale\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)
y_prob_rf = rf_model.predict_proba(X_test)[:,1]

print("Random Forest ROC-AUC:", roc_auc_score(y_test, y_prob_rf))
# Out:
# Random Forest ROC-AUC: 0.7481125600549073

# %%
feature_importance = pd.Series(
    rf_model.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

feature_importance.head(10)
# Out:
# Funds_Raised    0.466187
# Percentage      0.284375
# month           0.158601
# year            0.073363
# wave_month      0.017474
# dtype: float64

# %%
feature_importance.head(10).plot(kind='barh')
# Out:
# <Axes: >

# %%
import pickle

with open('../models/layoff_model.pkl', 'wb') as f:
    pickle.dump(rf_model, f)
